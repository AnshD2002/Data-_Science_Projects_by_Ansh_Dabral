# %% [markdown]
# # Creditcard Fraud Detection from Kaggle.com

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd 
import numpy as np 
import sklearn
import matplotlib.pyplot as plt

# %% [markdown]
# read CSV file as DataFrame

# %% [markdown]
# As u can see the Columns are names as V1, V2, … V28 contains strange values.
# this is because the values are highly confidential and connot be reaveal
# That's why PCA transformation is used to hide these values
#
#
# Principal component analysis (PCA) is a technique that transforms high-dimensions data into
# lower-dimensions while retaining as much information as possible

# %%
df = pd.read_csv("creditcard.csv")
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %% [markdown]
# Data Analysis

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# checking for null values

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# Visualizing "Fraud" & "Normal" data

# %%
count_class = pd.value_counts(df['Class'], sort = True)
count_class
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
label = ["Normal","Fraud"]
count_class.plot(kind = 'bar')
plt.xticks(range(2), label)
# Out:
# ([<matplotlib.axis.XTick at 0x7fd3e98e2310>,
# ...
#  [Text(0, 0, 'Normal'), Text(1, 0, 'Fraud')])

# %% [markdown]
# Spliting DataSet

# %%
x = df.drop(["Class"], axis = 1)
y = df.Class

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.25)

# %% [markdown]
# Training DataSet using different Models

# %% [markdown]
# Model traing using Linear regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain,ytrain)
model_score1=model.score(xtest,ytest)
model_score1
# Out:
# 0.560755851324577

# %% [markdown]
# Model traing using Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(xtrain,ytrain)
model_score2=model.score(xtest,ytest)
model_score2
# Out:
# 0.9991011488441336

# %% [markdown]
# Model traing using RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(max_samples=100, random_state=0)
model.fit(xtrain,ytrain)
model_score3=model.score(xtest,ytest)
model_score3
# Out:
# 0.9983708322799921

# %% [markdown]
# Model traing using SVC

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(xtrain,ytrain)
model_score4=model.score(xtest,ytest)
model_score4
# Out:
# 0.9983708322799921

# %%
#Observation:
#   As we can see different model have score different values i.e.
print("Predicted Score of Linear regression is ",model_score1)
print("Predicted Score of Decision Tree Classifier is ",model_score2)
print("Predicted Score of RandomForestClassifier is ",model_score3)
print("Predicted Score of SVC is ",model_score4)
# Out:
# Predicted Score of Linear regression is  0.560755851324577
# Predicted Score of Decision Tree Classifier is  0.9991011488441336
# Predicted Score of RandomForestClassifier is  0.9983708322799921
# Predicted Score of SVC is  0.9983708322799921

# %% [markdown]
# As we can see DecisionTreeClassifier has predicted highest value i.e. 99.83% than LR,RTC and SVC
